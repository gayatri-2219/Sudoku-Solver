# %% [markdown]
# <a href="https://colab.research.google.com/github/gayatri-2219/Sudoku-Solver/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EMPLOYEE RECORD DATASET**

# %%
import pandas as pd

# %%
import numpy as np

# %%
empdata={

      'joining_date':pd.date_range('2023-01-07',periods=20,freq='M'),
      'salary':np.random.randint(60000,100000,20),
      'age':np.random.randint(25,45,20)
      }

# %%
df=pd.DataFrame(empdata)

# %%
df.describe()
# Out:
#               joining_date       salary        age
# count                   20     20.00000  20.000000
# mean   2023-11-14 20:24:00  73662.40000  32.200000
# min    2023-01-31 00:00:00  61900.00000  25.000000
# 25%    2023-06-22 12:00:00  65165.00000  26.750000
# 50%    2023-11-15 00:00:00  70187.50000  32.000000
# 75%    2024-04-07 12:00:00  79826.50000  36.000000
# max    2024-08-31 00:00:00  94651.00000  44.000000
# std                    NaN  10617.73871   5.881282

# %%
df.shape
# Out:
# (20, 3)

# %%
df.isnull().sum()
# Out:
# joining_date    0
# salary          0
# age             0
# dtype: int64

# %%
df
# Out:
#    joining_date  salary  age
# 0    2023-01-31   70942   36
# 1    2023-02-28   76470   25
# 2    2023-03-31   63090   39
# 3    2023-04-30   67893   36
# 4    2023-05-31   69496   25
# 5    2023-06-30   66307   28
# 6    2023-07-31   94651   29
# 7    2023-08-31   63227   34
# 8    2023-09-30   82432   36
# 9    2023-10-31   78958   32
# 10   2023-11-30   64794   28
# 11   2023-12-31   83302   27
# 12   2024-01-31   94455   37
# 13   2024-02-29   61900   44
# 14   2024-03-31   91850   36
# 15   2024-04-30   68188   26
# 16   2024-05-31   74110   26
# 17   2024-06-30   65178   26
# 18   2024-07-31   65126   42
# 19   2024-08-31   70879   32
