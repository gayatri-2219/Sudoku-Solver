# %% [markdown]
# <a href="https://colab.research.google.com/github/gayatri-2219/Sudoku-Solver/blob/main/Session2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **1.STUDENT RECORD DATASET**

# %%
import pandas as pd

# %%
import numpy as np

# %%
data={'math score':np.random.randint(60,100,30),
      'reading_score':np.random.randint(55,98,30),
      'writing_score':np.random.randint(64,85,30),
      'placement_score':np.random.randint(75,100,30),
      'exam_dates':pd.date_range('2022-01-01',periods=30,freq='M')
      }

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     math score  reading_score  writing_score  placement_score exam_dates
# 0           93             76             73               83 2022-01-31
# 1           94             93             76               82 2022-02-28
# 2           72             87             65               76 2022-03-31
# 3           75             97             83               88 2022-04-30
# 4           72             76             76               80 2022-05-31
# 5           71             75             65               82 2022-06-30
# 6           67             81             81               92 2022-07-31
# 7           66             65             80               75 2022-08-31
# 8           66             57             84               89 2022-09-30
# 9           86             85             81               93 2022-10-31
# 10          62             81             83               99 2022-11-30
# 11          79             86             81               87 2022-12-31
# ...

# %%
df.describe()
# Out:
#        math score  reading_score  writing_score  placement_score  \
# count   30.000000      30.000000      30.000000        30.000000
# mean    77.666667      79.633333      74.933333        86.833333
# min     60.000000      57.000000      65.000000        75.000000
# 25%     66.250000      70.000000      69.000000        82.000000
# 50%     76.000000      81.000000      76.000000        87.000000
# 75%     89.750000      88.750000      80.750000        92.750000
# max     99.000000      97.000000      84.000000        99.000000
# std     12.089703      11.660376       6.506937         7.086088
#
#                 exam_dates
# count                   30
# mean   2023-04-15 18:24:00
# min    2022-01-31 00:00:00
# 25%    2022-09-07 12:00:00
# 50%    2023-04-15 00:00:00
# 75%    2023-11-22 12:00:00
# max    2024-06-30 00:00:00
# std                    NaN

# %%
df.shape
# Out:
# (30, 5)

# %%
df.isnull().sum()
# Out:
# math score         0
# reading_score      0
# writing_score      0
# placement_score    0
# exam_dates         0
# dtype: int64

# %% [markdown]
# ## **2. EMPLOYEE RECORD DATASET**

# %%
empdata={

      'joining_date':pd.date_range('2023-01-07',periods=20,freq='M'),
      'salary':np.random.randint(60000,100000,20),
      'age':np.random.randint(25,45,20)
      }

# %%
dfe=pd.DataFrame(empdata)

# %%
dfe
# Out:
#    joining_date  salary  age
# 0    2023-01-31   70172   28
# 1    2023-02-28   78129   35
# 2    2023-03-31   76696   26
# 3    2023-04-30   97850   27
# 4    2023-05-31   88982   40
# 5    2023-06-30   66693   35
# 6    2023-07-31   90802   35
# 7    2023-08-31   81781   37
# 8    2023-09-30   69866   38
# 9    2023-10-31   97372   25
# 10   2023-11-30   91346   30
# 11   2023-12-31   63348   30
# 12   2024-01-31   76488   28
# 13   2024-02-29   75670   44
# 14   2024-03-31   88645   35
# 15   2024-04-30   71074   40
# 16   2024-05-31   66583   32
# 17   2024-06-30   75784   42
# 18   2024-07-31   86985   33
# 19   2024-08-31   74099   40

# %%
dfe.describe()
# Out:
#               joining_date        salary        age
# count                   20     20.000000  20.000000
# mean   2023-11-14 20:24:00  79418.250000  34.000000
# min    2023-01-31 00:00:00  63348.000000  25.000000
# 25%    2023-06-22 12:00:00  70848.500000  29.500000
# 50%    2023-11-15 00:00:00  76592.000000  35.000000
# 75%    2024-04-07 12:00:00  88729.250000  38.500000
# max    2024-08-31 00:00:00  97850.000000  44.000000
# std                    NaN  10457.604873   5.638215

# %%
dfe.shape
# Out:
# (20, 3)

# %%
dfe.isnull().sum()
# Out:
# joining_date    0
# salary          0
# age             0
# dtype: int64

# %%
dfe[[salary,age]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-72c43d8201e5> in <cell line: 1>()
# ----> 1 dfe[[salary,age]]
#
# NameError: name 'dfe' is not defined
