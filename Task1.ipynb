# %% [markdown]
# <a href="https://colab.research.google.com/github/gayatri-2219/Sudoku-Solver/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Reading a dataset from kaggle**

# %% [markdown]
# Importing Pandas library

# %%
import pandas as pd

# %% [markdown]
# Create a data frame variable and load the data

# %%
df=pd.read_csv("/content/youtube.csv")

# %% [markdown]
# display first 5 rows

# %%
df.head()
# Out:
#   RANK             NAME_OF_CHANNEL TOTAL_NUMBER_OF_VIDEOS SUBSCRIBERS  \
# 0   #1                     MrBeast                    799        274M
# 1   #2                    T-Series                 21.12K        267M
# 2   #3  Cocomelon - Nursery Rhymes                  1.18K        176M
# 3   #4                   SET India                138.97K        173M
# 4   #5           ✿ Kids Diana Show                  1.22K        123M
#
#      VIEWS                  CATEGORY
# 0   50.98B   Entertainment
# 1  257.16B   Music
# 2  182.88B   Kids
# 3  164.71B   Entertainment
# 4   103.5B   Kids

# %% [markdown]
# display last 5 rows

# %%
df.tail()
# Out:
#      RANK       NAME_OF_CHANNEL TOTAL_NUMBER_OF_VIDEOS SUBSCRIBERS   VIEWS  \
# 495  #496  Smile Family Spanish                    563       20.5M   7.63B
# 496  #497  Marvel Entertainment                  8.97K       20.5M   6.01B
# 497  #498   5-Minute Crafts DIY                   6.1K       20.5M   5.16B
# 498  #499            SatoshiSea                      4       20.5M   1.55M
# 499  #500  Britain's Got Talent                  4.63K       20.4M  11.76B
#
#                      CATEGORY
# 495   Entertainment
# 496   Entertainment
# 497                       NaN
# 498                       NaN
# 499                       NaN

# %% [markdown]
# Check for missing values

# %%
df.isnull().sum()
# Out:
# RANK                      0
# NAME_OF_CHANNEL           7
# TOTAL_NUMBER_OF_VIDEOS    0
# SUBSCRIBERS               0
# VIEWS                     0
# CATEGORY                  8
# dtype: int64

# %% [markdown]
# To know the total no of rows and columns

# %%
df.shape
# Out:
# (500, 6)

# %% [markdown]
# to understand data description

# %%
df.describe()
# Out:
#        RANK NAME_OF_CHANNEL TOTAL_NUMBER_OF_VIDEOS SUBSCRIBERS  VIEWS  \
# count   500             493                    500         500    500
# unique  500             493                    444         246    471
# top      #1         MrBeast                  1.07K       20.9M  6.01B
# freq      1               1                      5          10      3
#
#                         CATEGORY
# count                        492
# unique                        32
# top      Entertainment
# freq                         186
